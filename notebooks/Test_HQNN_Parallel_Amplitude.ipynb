# %% [markdown]
# # Imports

# %%
import torch
import pennylane as qml
from pennylane import numpy as np
from loguru import logger
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='IPython')

import sys
import os
import time

logger.info(f"Current directory: {os.getcwd()}")
sys.path.append("../")

from src.nn.encodings.pennylane_templates import angle_embedding, amplitude_embedding, QAOA_embedding
from src.nn.encodings.IQP_embedding import custom_iqp_embedding
from src.nn.encodings.NQE_embedding import NQE_embedding
from src.nn.encodings.ring_embedding import ring_embedding
from src.nn.encodings.waterfall_embedding import waterfall_embedding

from src.nn.ansatz.no_entanglement_circuit import no_entanglement_random_circuit
from src.nn.ansatz.full_entanglement_circuit import full_entanglement_circuit
from src.nn.ansatz.NQ_circuit import NQ_circuit
from src.nn.ansatz.ring_circuit import ring_circuit

from src.nn.measurements.default import default_measurement

from src.nn.models.hybrid.HQNN_Parallel import HQNN_Parallel
from src.utils.training import Trainer
from src.utils.dataset import load_dataset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.backends.cudnn.benchmark = True
# Out:
# 2025-04-14 10:44:51.837 | INFO     | __main__:<module>:12 - Current directory: /Users/uribagi/Documents/GitHub/QML-Satellite-Image-Classification/notebooks

# %% [markdown]
# # Define embeddings

# %%
def build_embedding_configurations():
    """
    Dynamically create a list of embedding configurations based on parameter sweeps.
    """
    embedding_configurations = [{
        "name": "amplitude",
        "func": amplitude_embedding,
        "func_params": {
            "normalize": True,
            "pad_with": 0.0,
        }
    }]

    return embedding_configurations

# %% [markdown]
# # Define circuits

# %%
def build_circuit_configurations():
    num_layers = 2
    num_qubits_per_circuit = 8
    weights_strongly_entangled = torch.rand(num_layers, num_qubits_per_circuit, 3)% np.pi
    weights_nq = torch.rand(3 * 8, 2) % np.pi
    weights_no_ent = torch.rand(num_qubits_per_circuit, )  % np.pi

    configs = [{
        "name": f"no_entanglement",
        "func": no_entanglement_random_circuit,
        "func_params": {
            "num_layers": 1,
            "weights": weights_no_ent,
            "weight_shapes": {"weights": (num_qubits_per_circuit)},
        }
    }, {
        "name": f"full_entanglement",
        "func": full_entanglement_circuit,
        "func_params": {
            "num_layers": num_layers,
            "weights": weights_strongly_entangled,
            "weight_shapes": {"weights": (num_layers, num_qubits_per_circuit, 3)},
        }
    },{
        "name": f"nq_circuit",
        "func": NQ_circuit,
        "func_params": {
            "weights": weights_nq,
            "weight_shapes": {"weights": (3* 8, 2)},
        }
    },
        {
        "name": f"ring_circuit",
        "func": ring_circuit,
        "func_params": {
            "weights": weights_nq,
            "weight_shapes": {"weights": (3* num_qubits_per_circuit, 2)},
        }
    }]

    # Full Entanglement
    # NQ circuit
    # Ring circuit
    return configs

# %% [markdown]
# # Define measurements

# %%
measurement_configurations = [
    {
        "name": "defaultZ",
        "func": default_measurement,
        "func_params": {"observable": qml.PauliZ}
    },
    {
        "name": "defaultX",
        "func": default_measurement,
        "func_params": {"observable": qml.PauliX}
    },
    {
        "name": "defaultY",
        "func": default_measurement,
        "func_params": {"observable": qml.PauliY}
    }
]

# %% [markdown]
# # Dataset

# %%
dataset_configurations = [
    {
        "dataset_name": "EuroSAT",
        "limit": 500,
        "image_size": 16,
        "test_size": 0.2,
        "output": "np",
        "allowed_classes": [
            'AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway',
            'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake'
        ]
    }
]

# %% [markdown]
# # Hyperparameters

# %%
hyperparameter_configurations = [
    {
        "epochs": 30,
        "learning_rate": 0.01,
        "early_stopping": True,
        "patience": 10,
        "use_schedulefree": True,
        "use_quantum": True,
        "plot": False,
        "log_mlflow": True
    }
]

# %% [markdown]
# # Helper function

# %%
def run_experiment(
    dataset_cfg,
    embedding_cfg,
    circuit_cfg,
    measurement_cfg,
    hparams
):
    """
    Prepare data, create model, trainer, and run training for one combination of config.
    """
    # Unpack dataset settings
    dataset_name = dataset_cfg["dataset_name"]
    limit = dataset_cfg["limit"]
    image_size = dataset_cfg["image_size"]
    test_size = dataset_cfg["test_size"]
    output = dataset_cfg["output"]
    allowed_classes = dataset_cfg["allowed_classes"]
    n_classes = len(allowed_classes)

    # Unpack hyperparameters
    epochs = hparams["epochs"]
    lr = hparams["learning_rate"]
    early_stopping = hparams["early_stopping"]
    patience = hparams["patience"]
    use_schedulefree = hparams["use_schedulefree"]
    use_quantum = hparams["use_quantum"]
    plot = hparams["plot"]
    log_mlflow = hparams["log_mlflow"]

    # The circuit dictionary also includes the chosen qkernel_shape
    if use_quantum:
        # Loguru info: Start of run
        logger.info(f"Starting run: dataset={dataset_name}, "
                f"embedding={embedding_cfg['name']}, "
                f"circuit={circuit_cfg['name']}, measurement={measurement_cfg['name']}, "
                f"epochs={epochs}, lr={lr}")

        run_name = (
            f"HQNN_Parallel_{dataset_name}_{image_size}x{image_size}_"
            f"emb={embedding_cfg['name']}_circuit={circuit_cfg['name']}_meas={measurement_cfg['name']}_"
            f"lr={lr}_ep={epochs}"
        )
    # Create a dictionary of all configurations for MLflow
        mlflow_params = {
            # Dataset parameters
            "dataset_name": dataset_name,
            "limit": limit,
            "image_size": image_size,
            "test_size": test_size,
            "allowed_classes": str(allowed_classes),  # Convert list to string

            # Embedding parameters
            "embedding_name": embedding_cfg['name'],

            # Circuit parameters
            "circuit_name": circuit_cfg['name'],

            # Measurement parameters
            "measurement_name": measurement_cfg['name'],

            # Any other relevant parameters you want to track
            "run_timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        }

        embedding_params={
            "func": embedding_cfg["func"],
            "func_params": embedding_cfg["func_params"]
        }

        variational_params={
                "func": circuit_cfg["func"],
                "func_params": circuit_cfg["func_params"]  # includes 'weights' re-init
            }
        measurement_params={
            "func": measurement_cfg["func"],
            "func_params": measurement_cfg["func_params"]
        }

    else:
        logger.info(f"Starting Classic run: dataset={dataset_name}, "
                f"epochs={epochs}, lr={lr}")

        run_name = (
            f"HQNN_Parallel_{dataset_name}_{image_size}x{image_size}_"
            f"classic_"
            f"lr={lr}_ep={epochs}"
        )
        mlflow_params = {}
        embedding_params={}
        variational_params={}
        measurement_params={}

    mlflow_project_name = f"{dataset_name} {image_size}x{image_size}"

    # 1. Load Dataset
    train_loader, val_loader = load_dataset(
        dataset_name,
        output,
        limit,
        allowed_classes,
        image_size,
        test_size,
    )

    # 2. Create model
    model = HQNN_Parallel(
        embedding_params=embedding_params,
        variational_params=variational_params,
        measurement_params=measurement_params,
        n_classes=n_classes,
        use_quantum=use_quantum,
        dataset=dataset_name,
        input_size=image_size
    )

    # 3. Create Trainer
    trainer = Trainer(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        epochs=epochs,
        early_stopping=early_stopping,
        patience=patience,
        log=log_mlflow,
        mlflow_project=mlflow_project_name,
        mlflow_run_name=run_name,
        use_quantum=use_quantum,
        plot=plot,
        allowed_classes=allowed_classes,
        lr=lr,
        use_schedulefree=use_schedulefree,
        mlflow_params=mlflow_params,
    )

    logger.debug(f"Trainer created: early_stopping={early_stopping}, "
                 f"patience={patience}, log_mlflow={log_mlflow}")

    # 4. Train
    trainer.fit()

    logger.info(f"Finished run: {run_name}")

# %% [markdown]
# # Main loop

# %%
# 1. Build all embedding configs (with angle, iqp, nqe, qaoa sweeps, etc.)
dynamic_embedding_configurations = build_embedding_configurations()

# 2. Build circuit configs for qkernel_shape in [2,3,5]
circuit_configurations = build_circuit_configurations()

# 3. Nested loops
for hp_cfg in hyperparameter_configurations:
    for dataset_cfg in dataset_configurations:
        if not hp_cfg["use_quantum"]:
            # Run the experiment
            run_experiment(
                dataset_cfg=dataset_cfg,
                embedding_cfg={},
                circuit_cfg={},
                measurement_cfg={},
                hparams=hp_cfg
            )
            continue

        for emb_cfg in dynamic_embedding_configurations:
            for cir_cfg in circuit_configurations:
                for meas_cfg in measurement_configurations:
                    run_experiment(
                        dataset_cfg=dataset_cfg,
                        embedding_cfg=emb_cfg,
                        circuit_cfg=cir_cfg,
                        measurement_cfg=meas_cfg,
                        hparams=hp_cfg

                    )
# Out:
# 2025-04-14 10:44:53.710 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=no_entanglement, measurement=defaultZ, epochs=30, lr=0.01
# 2025-04-14 10:45:42.028 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 10:45:43.781 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 1.9127, Train Acc = 26.43%, Val Loss = 1.7381, Val Acc = 31.50%
# 2025-04-14 10:45:45.335 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.6869, Train Acc = 34.05%, Val Loss = 1.6264, Val Acc = 34.10%
# 2025-04-14 10:45:46.940 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.5484, Train Acc = 40.77%, Val Loss = 1.5026, Val Acc = 43.60%
# 2025-04-14 10:45:48.518 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.3970, Train Acc = 48.85%, Val Loss = 1.3566, Val Acc = 51.50%
# 2025-04-14 10:45:50.122 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.2901, Train Acc = 53.65%, Val Loss = 1.2676, Val Acc = 54.50%
# 2025-04-14 10:45:51.728 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 1.2101, Train Acc = 56.40%, Val Loss = 1.2117, Val Acc = 55.90%
# 2025-04-14 10:45:53.339 | DEBUG    | src.utils.training:fit:226 - Epoch [7/30]: Train Loss = 1.1477, Train Acc = 58.92%, Val Loss = 1.1657, Val Acc = 57.50%
# 2025-04-14 10:45:54.893 | DEBUG    | src.utils.training:fit:226 - Epoch [8/30]: Train Loss = 1.1106, Train Acc = 59.58%, Val Loss = 1.1338, Val Acc = 59.60%
# 2025-04-14 10:45:56.432 | DEBUG    | src.utils.training:fit:226 - Epoch [9/30]: Train Loss = 1.0727, Train Acc = 60.55%, Val Loss = 1.1089, Val Acc = 60.20%
# 2025-04-14 10:45:58.048 | DEBUG    | src.utils.training:fit:226 - Epoch [10/30]: Train Loss = 1.0388, Train Acc = 62.30%, Val Loss = 1.0869, Val Acc = 61.00%
# 2025-04-14 10:45:59.675 | DEBUG    | src.utils.training:fit:226 - Epoch [11/30]: Train Loss = 1.0157, Train Acc = 62.35%, Val Loss = 1.0692, Val Acc = 62.30%
# 2025-04-14 10:46:01.274 | DEBUG    | src.utils.training:fit:226 - Epoch [12/30]: Train Loss = 0.9899, Train Acc = 63.20%, Val Loss = 1.0534, Val Acc = 62.80%
# 2025-04-14 10:46:02.860 | DEBUG    | src.utils.training:fit:226 - Epoch [13/30]: Train Loss = 0.9666, Train Acc = 65.12%, Val Loss = 1.0366, Val Acc = 64.00%
# 2025-04-14 10:46:04.373 | DEBUG    | src.utils.training:fit:226 - Epoch [14/30]: Train Loss = 0.9448, Train Acc = 65.33%, Val Loss = 1.0231, Val Acc = 63.80%
# 2025-04-14 10:46:05.924 | DEBUG    | src.utils.training:fit:226 - Epoch [15/30]: Train Loss = 0.9315, Train Acc = 65.62%, Val Loss = 1.0163, Val Acc = 64.60%
# 2025-04-14 10:46:07.522 | DEBUG    | src.utils.training:fit:226 - Epoch [16/30]: Train Loss = 0.9185, Train Acc = 66.80%, Val Loss = 1.0087, Val Acc = 64.10%
# 2025-04-14 10:46:09.139 | DEBUG    | src.utils.training:fit:226 - Epoch [17/30]: Train Loss = 0.8938, Train Acc = 66.92%, Val Loss = 1.0028, Val Acc = 64.40%
# 2025-04-14 10:46:10.748 | DEBUG    | src.utils.training:fit:226 - Epoch [18/30]: Train Loss = 0.8828, Train Acc = 67.17%, Val Loss = 0.9977, Val Acc = 64.70%
# 2025-04-14 10:46:12.392 | DEBUG    | src.utils.training:fit:226 - Epoch [19/30]: Train Loss = 0.8658, Train Acc = 68.03%, Val Loss = 0.9952, Val Acc = 65.30%
# 2025-04-14 10:46:14.051 | DEBUG    | src.utils.training:fit:226 - Epoch [20/30]: Train Loss = 0.8507, Train Acc = 68.80%, Val Loss = 0.9924, Val Acc = 65.70%
# 2025-04-14 10:46:15.628 | DEBUG    | src.utils.training:fit:226 - Epoch [21/30]: Train Loss = 0.8434, Train Acc = 68.85%, Val Loss = 0.9916, Val Acc = 65.50%
# 2025-04-14 10:46:17.246 | DEBUG    | src.utils.training:fit:226 - Epoch [22/30]: Train Loss = 0.8263, Train Acc = 69.83%, Val Loss = 0.9895, Val Acc = 65.60%
# 2025-04-14 10:46:18.856 | DEBUG    | src.utils.training:fit:226 - Epoch [23/30]: Train Loss = 0.8125, Train Acc = 70.25%, Val Loss = 0.9891, Val Acc = 65.80%
# 2025-04-14 10:46:20.476 | DEBUG    | src.utils.training:fit:226 - Epoch [24/30]: Train Loss = 0.7994, Train Acc = 71.12%, Val Loss = 0.9903, Val Acc = 66.10%
# 2025-04-14 10:46:22.082 | DEBUG    | src.utils.training:fit:226 - Epoch [25/30]: Train Loss = 0.7884, Train Acc = 71.78%, Val Loss = 0.9920, Val Acc = 66.00%
# 2025-04-14 10:46:23.686 | DEBUG    | src.utils.training:fit:226 - Epoch [26/30]: Train Loss = 0.7763, Train Acc = 71.78%, Val Loss = 0.9921, Val Acc = 66.00%
# 2025-04-14 10:46:25.287 | DEBUG    | src.utils.training:fit:226 - Epoch [27/30]: Train Loss = 0.7699, Train Acc = 71.50%, Val Loss = 0.9908, Val Acc = 65.20%
# 2025-04-14 10:46:26.846 | DEBUG    | src.utils.training:fit:226 - Epoch [28/30]: Train Loss = 0.7578, Train Acc = 72.67%, Val Loss = 0.9890, Val Acc = 65.00%
# 2025-04-14 10:46:28.435 | DEBUG    | src.utils.training:fit:226 - Epoch [29/30]: Train Loss = 0.7509, Train Acc = 72.78%, Val Loss = 0.9859, Val Acc = 65.50%
# 2025-04-14 10:46:30.021 | DEBUG    | src.utils.training:fit:226 - Epoch [30/30]: Train Loss = 0.7477, Train Acc = 73.45%, Val Loss = 0.9847, Val Acc = 65.70%
# 2025-04-14 10:46:30.024 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=no_entanglement_meas=defaultZ_lr=0.01_ep=30
# 2025-04-14 10:46:30.024 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=no_entanglement, measurement=defaultX, epochs=30, lr=0.01
# 2025-04-14 10:47:18.817 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14
# 2025-04-14 10:48:15.055 | DEBUG    | src.utils.training:fit:226 - Epoch [25/30]: Train Loss = 0.9882, Train Acc = 64.42%, Val Loss = 1.1418, Val Acc = 56.10%
# 2025-04-14 10:48:17.281 | DEBUG    | src.utils.training:fit:226 - Epoch [26/30]: Train Loss = 0.9768, Train Acc = 65.30%, Val Loss = 1.1290, Val Acc = 58.30%
# 2025-04-14 10:48:19.478 | DEBUG    | src.utils.training:fit:226 - Epoch [27/30]: Train Loss = 0.9715, Train Acc = 64.83%, Val Loss = 1.1202, Val Acc = 59.10%
# 2025-04-14 10:48:21.690 | DEBUG    | src.utils.training:fit:226 - Epoch [28/30]: Train Loss = 0.9672, Train Acc = 64.97%, Val Loss = 1.1153, Val Acc = 58.60%
# 2025-04-14 10:48:23.886 | DEBUG    | src.utils.training:fit:226 - Epoch [29/30]: Train Loss = 0.9625, Train Acc = 65.30%, Val Loss = 1.0989, Val Acc = 59.50%
# 2025-04-14 10:48:26.155 | DEBUG    | src.utils.training:fit:226 - Epoch [30/30]: Train Loss = 0.9648, Train Acc = 65.58%, Val Loss = 1.1050, Val Acc = 59.60%
# 2025-04-14 10:48:26.159 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=no_entanglement_meas=defaultX_lr=0.01_ep=30
# 2025-04-14 10:48:26.159 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=no_entanglement, measurement=defaultY, epochs=30, lr=0.01
# 2025-04-14 10:49:14.525 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 10:49:17.980 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 2.1082, Train Acc = 19.23%, Val Loss = 1.9195, Val Acc = 21.90%
# 2025-04-14 10:49:21.345 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.8705, Train Acc = 24.65%, Val Loss = 1.8298, Val Acc = 27.50%
# 2025-04-14 10:49:24.725 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.7704, Train Acc = 30.38%, Val Loss = 1.7068, Val Acc = 33.90%
# 2025-04-14 10:49:28.113 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.7182, Train Acc = 32.75%, Val Loss = 1.6636, Val Acc = 34.70%
# 2025-04-14 10:49:31.507 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.6853, Train Acc = 34.25%, Val Loss = 1.6425, Val Acc = 35.50%
# 2025-04-14 10:49:34.867 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 1.6226, Train Acc = 35.75%, Val Loss = 1.5962, Val Acc = 37.30%
# 2025-04-14 10:49:38.235 | DEBUG    | src.utils.training:fit:226 - Epoch [7/30]: Train Loss = 1.5965, Train Acc = 36.85%, Val Loss = 1.5850, Val Acc = 37.30%
# 2025-04-14 10:49:41.567 | DEBUG    | src.utils.training:fit:226 - Epoch [8/30]: Train Loss = 1.5795, Train Acc = 37.62%, Val Loss = 1.5597, Val Acc = 39.10%
# 2025-04-14 10:49:45.002 | DEBUG    | src.utils.training:fit:226 - Epoch [9/30]: Train Loss = 1.5700, Train Acc = 38.12%, Val Loss = 1.5798, Val Acc = 38.20%
# 2025-04-14 10:49:48.383 | DEBUG    | src.utils.training:fit:226 - Epoch [10/30]: Train Loss = 1.5508, Train Acc = 39.40%, Val Loss = 1.5714, Val Acc = 41.40%
# 2025-04-14 10:49:51.770 | DEBUG    | src.utils.training:fit:226 - Epoch [11/30]: Train Loss = 1.5109, Train Acc = 40.35%, Val Loss = 1.4909, Val Acc = 43.30%
# 2025-04-14 10:49:55.148 | DEBUG    | src.utils.training:fit:226 - Epoch [12/30]: Train Loss = 1.5233, Train Acc = 42.10%, Val Loss = 1.5011, Val Acc = 42.70%
# 2025-04-14 10:49:58.476 | DEBUG    | src.utils.training:fit:226 - Epoch [13/30]: Train Loss = 1.5102, Train Acc = 42.23%, Val Loss = 1.5259, Val Acc = 41.30%
# 2025-04-14 10:50:01.866 | DEBUG    | src.utils.training:fit:226 - Epoch [14/30]: Train Loss = 1.4533, Train Acc = 45.85%, Val Loss = 1.4252, Val Acc = 45.30%
# 2025-04-14 10:50:05.237 | DEBUG    | src.utils.training:fit:226 - Epoch [15/30]: Train Loss = 1.4517, Train Acc = 46.00%, Val Loss = 1.4501, Val Acc = 43.80%
# 2025-04-14 10:50:08.644 | DEBUG    | src.utils.training:fit:226 - Epoch [16/30]: Train Loss = 1.4465, Train Acc = 45.25%, Val Loss = 1.4330, Val Acc = 46.80%
# 2025-04-14 10:50:11.980 | DEBUG    | src.utils.training:fit:226 - Epoch [17/30]: Train Loss = 1.4243, Train Acc = 46.77%, Val Loss = 1.4467, Val Acc = 48.20%
# 2025-04-14 10:50:15.331 | DEBUG    | src.utils.training:fit:226 - Epoch [18/30]: Train Loss = 1.4234, Train Acc = 46.83%, Val Loss = 1.4813, Val Acc = 44.60%
# 2025-04-14 10:50:18.653 | DEBUG    | src.utils.training:fit:226 - Epoch [19/30]: Train Loss = 1.4037, Train Acc = 47.12%, Val Loss = 1.4528, Val Acc = 44.90%
# 2025-04-14 10:50:22.022 | DEBUG    | src.utils.training:fit:226 - Epoch [20/30]: Train Loss = 1.3808, Train Acc = 48.38%, Val Loss = 1.4499, Val Acc = 45.70%
# 2025-04-14 10:50:25.394 | DEBUG    | src.utils.training:fit:226 - Epoch [21/30]: Train Loss = 1.3709, Train Acc = 49.23%, Val Loss = 1.4668, Val Acc = 45.70%
# 2025-04-14 10:50:28.742 | DEBUG    | src.utils.training:fit:226 - Epoch [22/30]: Train Loss = 1.3927, Train Acc = 48.45%, Val Loss = 1.4488, Val Acc = 45.60%
# 2025-04-14 10:50:32.140 | DEBUG    | src.utils.training:fit:226 - Epoch [23/30]: Train Loss = 1.3384, Train Acc = 50.73%, Val Loss = 1.3925, Val Acc = 49.80%
# 2025-04-14 10:50:35.485 | DEBUG    | src.utils.training:fit:226 - Epoch [24/30]: Train Loss = 1.3285, Train Acc = 51.55%, Val Loss = 1.4038, Val Acc = 47.50%
# 2025-04-14 10:50:39.533 | DEBUG    | src.utils.training:fit:226 - Epoch [25/30]: Train Loss = 1.3238, Train Acc = 50.88%, Val Loss = 1.3702, Val Acc = 49.90%
# 2025-04-14 10:50:42.920 | DEBUG    | src.utils.training:fit:226 - Epoch [26/30]: Train Loss = 1.3299, Train Acc = 50.67%, Val Loss = 1.3348, Val Acc = 51.60%
# 2025-04-14 10:50:46.269 | DEBUG    | src.utils.training:fit:226 - Epoch [27/30]: Train Loss = 1.3253, Train Acc = 51.48%, Val Loss = 1.3691, Val Acc = 49.00%
# 2025-04-14 10:50:49.640 | DEBUG    | src.utils.training:fit:226 - Epoch [28/30]: Train Loss = 1.2895, Train Acc = 53.15%, Val Loss = 1.3243, Val Acc = 51.90%
# 2025-04-14 10:50:52.978 | DEBUG    | src.utils.training:fit:226 - Epoch [29/30]: Train Loss = 1.3028, Train Acc = 52.75%, Val Loss = 1.3145, Val Acc = 52.90%
# 2025-04-14 10:50:56.323 | DEBUG    | src.utils.training:fit:226 - Epoch [30/30]: Train Loss = 1.2907, Train Acc = 53.38%, Val Loss = 1.2947, Val Acc = 51.50%
# 2025-04-14 10:50:56.326 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=no_entanglement_meas=defaultY_lr=0.01_ep=30
# 2025-04-14 10:50:56.327 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=full_entanglement, measurement=defaultZ, epochs=30, lr=0.01
# 2025-04-14 10:51:44.762 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 10:51:50.666 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 1.9500, Train Acc = 21.12%, Val Loss = 1.6929, Val Acc = 30.50%
# 2025-04-14 10:51:56.385 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.6874, Train Acc = 30.95%, Val Loss = 1.6260, Val Acc = 35.00%
# 2025-04-14 10:52:02.082 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1
# 2025-04-14 10:54:13.857 | DEBUG    | src.utils.training:fit:226 - Epoch [26/30]: Train Loss = 0.8086, Train Acc = 70.65%, Val Loss = 0.9668, Val Acc = 66.30%
# 2025-04-14 10:54:20.311 | DEBUG    | src.utils.training:fit:226 - Epoch [27/30]: Train Loss = 0.7998, Train Acc = 70.95%, Val Loss = 0.9613, Val Acc = 66.50%
# 2025-04-14 10:54:26.303 | DEBUG    | src.utils.training:fit:226 - Epoch [28/30]: Train Loss = 0.7961, Train Acc = 70.80%, Val Loss = 0.9545, Val Acc = 66.90%
# 2025-04-14 10:54:32.010 | DEBUG    | src.utils.training:fit:226 - Epoch [29/30]: Train Loss = 0.7791, Train Acc = 71.00%, Val Loss = 0.9505, Val Acc = 67.50%
# 2025-04-14 10:54:37.793 | DEBUG    | src.utils.training:fit:226 - Epoch [30/30]: Train Loss = 0.7789, Train Acc = 71.33%, Val Loss = 0.9444, Val Acc = 67.60%
# 2025-04-14 10:54:37.797 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=full_entanglement_meas=defaultZ_lr=0.01_ep=30
# 2025-04-14 10:54:37.798 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=full_entanglement, measurement=defaultX, epochs=30, lr=0.01
# 2025-04-14 10:55:26.491 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 10:55:33.421 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 1.9779, Train Acc = 21.88%, Val Loss = 1.7298, Val Acc = 31.20%
# 2025-04-14 10:55:40.281 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.6775, Train Acc = 32.98%, Val Loss = 1.6644, Val Acc = 33.10%
# 2025-04-14 10:55:47.177 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.6019, Train Acc = 36.38%, Val Loss = 1.6262, Val Acc = 35.60%
# 2025-04-14 10:55:54.161 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.5323, Train Acc = 40.20%, Val Loss = 1.5634, Val Acc = 40.10%
# 2025-04-14 10:56:00.888 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.4607, Train Acc = 43.83%, Val Loss = 1.4889, Val Acc = 42.00%
# 2025-04-14 10:56:07.714 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 1.4102, Train Acc = 46.77%, Val Loss = 1.4283, Val Acc = 44.50%
# 2025-04-14 10:56:14.509 | DEBUG    | src.utils.training:fit:226 - Epoch [7/30]: Train Loss = 1.3572, Train Acc = 48.10%, Val Loss = 1.3860, Val Acc = 45.60%
# 2025-04-14 10:56:21.328 | DEBUG    | src.utils.training:fit:226 - Epoch [8/30]: Train Loss = 1.3264, Train Acc = 49.45%, Val Loss = 1.3624, Val Acc = 46.50%
# 2025-04-14 10:56:28.119 | DEBUG    | src.utils.training:fit:226 - Epoch [9/30]: Train Loss = 1.3048, Train Acc = 49.90%, Val Loss = 1.3409, Val Acc = 48.50%
# 2025-04-14 10:56:34.953 | DEBUG    | src.utils.training:fit:226 - Epoch [10/30]: Train Loss = 1.2697, Train Acc = 51.90%, Val Loss = 1.3196, Val Acc = 50.00%
# 2025-04-14 10:56:41.707 | DEBUG    | src.utils.training:fit:226 - Epoch [11/30]: Train Loss = 1.2436, Train Acc = 53.02%, Val Loss = 1.3016, Val Acc = 50.20%
# 2025-04-14 10:56:48.452 | DEBUG    | src.utils.training:fit:226 - Epoch [12/30]: Train Loss = 1.2113, Train Acc = 53.95%, Val Loss = 1.2879, Val Acc = 50.30%
# 2025-04-14 10:56:55.239 | DEBUG    | src.utils.training:fit:226 - Epoch [13/30]: Train Loss = 1.1882, Train Acc = 55.25%, Val Loss = 1.2713, Val Acc = 51.70%
# 2025-04-14 10:57:02.138 | DEBUG    | src.utils.training:fit:226 - Epoch [14/30]: Train Loss = 1.1569, Train Acc = 56.85%, Val Loss = 1.2547, Val Acc = 53.40%
# 2025-04-14 10:57:08.980 | DEBUG    | src.utils.training:fit:226 - Epoch [15/30]: Train Loss = 1.1293, Train Acc = 57.65%, Val Loss = 1.2379, Val Acc = 54.60%
# 2025-04-14 10:57:15.734 | DEBUG    | src.utils.training:fit:226 - Epoch [16/30]: Train Loss = 1.1123, Train Acc = 58.77%, Val Loss = 1.2210, Val Acc = 55.20%
# 2025-04-14 10:57:22.585 | DEBUG    | src.utils.training:fit:226 - Epoch [17/30]: Train Loss = 1.0869, Train Acc = 59.52%, Val Loss = 1.2117, Val Acc = 55.40%
# 2025-04-14 10:57:29.407 | DEBUG    | src.utils.training:fit:226 - Epoch [18/30]: Train Loss = 1.0676, Train Acc = 59.95%, Val Loss = 1.1973, Val Acc = 55.50%
# 2025-04-14 10:57:36.261 | DEBUG    | src.utils.training:fit:226 - Epoch [19/30]: Train Loss = 1.0455, Train Acc = 61.02%, Val Loss = 1.1815, Val Acc = 56.60%
# 2025-04-14 10:57:43.018 | DEBUG    | src.utils.training:fit:226 - Epoch [20/30]: Train Loss = 1.0285, Train Acc = 61.20%, Val Loss = 1.1737, Val Acc = 56.20%
# 2025-04-14 10:57:49.919 | DEBUG    | src.utils.training:fit:226 - Epoch [21/30]: Train Loss = 1.0120, Train Acc = 62.60%, Val Loss = 1.1665, Val Acc = 56.60%
# 2025-04-14 10:57:56.723 | DEBUG    | src.utils.training:fit:226 - Epoch [22/30]: Train Loss = 0.9934, Train Acc = 63.00%, Val Loss = 1.1535, Val Acc = 57.20%
# 2025-04-14 10:58:03.512 | DEBUG    | src.utils.training:fit:226 - Epoch [23/30]: Train Loss = 0.9820, Train Acc = 63.02%, Val Loss = 1.1411, Val Acc = 57.40%
# 2025-04-14 10:58:10.405 | DEBUG    | src.utils.training:fit:226 - Epoch [24/30]: Train Loss = 0.9692, Train Acc = 63.73%, Val Loss = 1.1305, Val Acc = 58.20%
# 2025-04-14 10:58:17.193 | DEBUG    | src.utils.training:fit:226 - Epoch [25/30]: Train Loss = 0.9492, Train Acc = 64.00%, Val Loss = 1.1199, Val Acc = 59.20%
# 2025-04-14 10:58:23.947 | DEBUG    | src.utils.training:fit:226 - Epoch [26/30]: Train Loss = 0.9389, Train Acc = 65.65%, Val Loss = 1.1110, Val Acc = 60.20%
# 2025-04-14 10:58:31.082 | DEBUG    | src.utils.training:fit:226 - Epoch [27/30]: Train Loss = 0.9195, Train Acc = 65.80%, Val Loss = 1.1003, Val Acc = 61.10%
# 2025-04-14 10:58:37.876 | DEBUG    | src.utils.training:fit:226 - Epoch [28/30]: Train Loss = 0.9145, Train Acc = 65.92%, Val Loss = 1.0917, Val Acc = 61.70%
# 2025-04-14 10:58:44.775 | DEBUG    | src.utils.training:fit:226 - Epoch [29/30]: Train Loss = 0.9028, Train Acc = 66.35%, Val Loss = 1.0833, Val Acc = 62.40%
# 2025-04-14 10:58:51.614 | DEBUG    | src.utils.training:fit:226 - Epoch [30/30]: Train Loss = 0.8959, Train Acc = 66.75%, Val Loss = 1.0751, Val Acc = 62.80%
# 2025-04-14 10:58:51.618 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=full_entanglement_meas=defaultX_lr=0.01_ep=30
# 2025-04-14 10:58:51.619 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=full_entanglement, measurement=defaultY, epochs=30, lr=0.01
# 2025-04-14 10:59:40.355 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 10:59:48.327 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 2.0280, Train Acc = 21.82%, Val Loss = 1.7505, Val Acc = 32.80%
# 2025-04-14 10:59:56.432 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.7381, Train Acc = 33.05%, Val Loss = 1.6278, Val Acc = 36.60%
# 2025-04-14 11:00:04.385 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.6146, Train Acc = 36.75%, Val Loss = 1.5263, Val Acc = 38.30%
# 2025-04-14 11:00:12.263 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.5038, Train Acc = 42.67%, Val Loss = 1.4405, Val Acc = 45.90%
# 2025-04-14 11:00:20.224 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.4321, Train Acc = 45.83%, Val Loss = 1.3778, Val Acc = 49.70%
# 2025-04-14 11:00:28.227 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 1
# 2025-04-14 11:03:24.441 | DEBUG    | src.utils.training:fit:226 - Epoch [28/30]: Train Loss = 0.8145, Train Acc = 70.22%, Val Loss = 0.8924, Val Acc = 69.00%
# 2025-04-14 11:03:32.472 | DEBUG    | src.utils.training:fit:226 - Epoch [29/30]: Train Loss = 0.8092, Train Acc = 70.45%, Val Loss = 0.8870, Val Acc = 68.40%
# 2025-04-14 11:03:40.332 | DEBUG    | src.utils.training:fit:226 - Epoch [30/30]: Train Loss = 0.8094, Train Acc = 70.30%, Val Loss = 0.8830, Val Acc = 68.50%
# 2025-04-14 11:03:40.336 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=full_entanglement_meas=defaultY_lr=0.01_ep=30
# 2025-04-14 11:03:40.336 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=nq_circuit, measurement=defaultZ, epochs=30, lr=0.01
# 2025-04-14 11:04:29.098 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 11:05:09.124 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 1.9252, Train Acc = 26.35%, Val Loss = 1.7105, Val Acc = 35.90%
# 2025-04-14 11:05:49.102 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.6357, Train Acc = 37.45%, Val Loss = 1.5892, Val Acc = 41.50%
# 2025-04-14 11:06:29.003 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.4353, Train Acc = 45.33%, Val Loss = 1.5964, Val Acc = 39.50%
# 2025-04-14 11:07:08.993 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.1670, Train Acc = 56.35%, Val Loss = 1.4831, Val Acc = 47.70%
# 2025-04-14 11:07:48.780 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 0.8866, Train Acc = 67.80%, Val Loss = 1.5491, Val Acc = 51.00%
# 2025-04-14 11:08:29.109 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 0.6456, Train Acc = 77.90%, Val Loss = 1.7473, Val Acc = 53.90%
# 2025-04-14 11:09:09.328 | DEBUG    | src.utils.training:fit:226 - Epoch [7/30]: Train Loss = 0.4996, Train Acc = 82.22%, Val Loss = 2.0182, Val Acc = 52.60%
# 2025-04-14 11:09:49.325 | DEBUG    | src.utils.training:fit:226 - Epoch [8/30]: Train Loss = 0.3979, Train Acc = 86.30%, Val Loss = 2.2796, Val Acc = 55.60%
# 2025-04-14 11:10:29.647 | DEBUG    | src.utils.training:fit:226 - Epoch [9/30]: Train Loss = 0.2930, Train Acc = 89.70%, Val Loss = 2.5073, Val Acc = 55.20%
# 2025-04-14 11:11:09.737 | DEBUG    | src.utils.training:fit:226 - Epoch [10/30]: Train Loss = 0.2656, Train Acc = 91.03%, Val Loss = 2.8231, Val Acc = 55.70%
# 2025-04-14 11:11:49.930 | DEBUG    | src.utils.training:fit:226 - Epoch [11/30]: Train Loss = 0.2623, Train Acc = 91.75%, Val Loss = 3.0895, Val Acc = 55.70%
# 2025-04-14 11:12:30.108 | DEBUG    | src.utils.training:fit:226 - Epoch [12/30]: Train Loss = 0.2203, Train Acc = 92.62%, Val Loss = 3.3349, Val Acc = 54.20%
# 2025-04-14 11:13:10.296 | DEBUG    | src.utils.training:fit:226 - Epoch [13/30]: Train Loss = 0.3565, Train Acc = 89.75%, Val Loss = 3.4077, Val Acc = 54.80%
# 2025-04-14 11:13:50.470 | INFO     | src.utils.training:fit:214 - Early stopping at epoch 14
# 2025-04-14 11:13:50.478 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=nq_circuit_meas=defaultZ_lr=0.01_ep=30
# 2025-04-14 11:13:50.478 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=nq_circuit, measurement=defaultX, epochs=30, lr=0.01
# 2025-04-14 11:14:39.330 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 11:15:22.372 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 2.0237, Train Acc = 22.43%, Val Loss = 1.7374, Val Acc = 32.70%
# 2025-04-14 11:16:05.137 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.6832, Train Acc = 35.38%, Val Loss = 1.5536, Val Acc = 40.50%
# 2025-04-14 11:16:48.059 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.6661, Train Acc = 37.50%, Val Loss = 1.6905, Val Acc = 35.00%
# 2025-04-14 11:17:31.176 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.5965, Train Acc = 39.73%, Val Loss = 1.6271, Val Acc = 38.50%
# 2025-04-14 11:18:15.191 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.4881, Train Acc = 42.75%, Val Loss = 1.4941, Val Acc = 44.20%
# 2025-04-14 11:18:59.667 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 1.3964, Train Acc = 46.70%, Val Loss = 1.4175, Val Acc = 46.10%
# 2025-04-14 11:19:43.829 | DEBUG    | src.utils.training:fit:226 - Epoch [7/30]: Train Loss = 1.3132, Train Acc = 49.83%, Val Loss = 1.3797, Val Acc = 48.00%
# 2025-04-14 11:20:27.821 | DEBUG    | src.utils.training:fit:226 - Epoch [8/30]: Train Loss = 1.2212, Train Acc = 53.85%, Val Loss = 1.3291, Val Acc = 50.20%
# 2025-04-14 11:21:11.646 | DEBUG    | src.utils.training:fit:226 - Epoch [9/30]: Train Loss = 1.1647, Train Acc = 56.25%, Val Loss = 1.3500, Val Acc = 51.70%
# 2025-04-14 11:21:55.527 | DEBUG    | src.utils.training:fit:226 - Epoch [10/30]: Train Loss = 1.0716, Train Acc = 60.60%, Val Loss = 1.2950, Val Acc = 54.40%
# 2025-04-14 11:22:39.344 | DEBUG    | src.utils.training:fit:226 - Epoch [11/30]: Train Loss = 0.9654, Train Acc = 65.17%, Val Loss = 1.2860, Val Acc = 55.70%
# 2025-04-14 11:23:23.198 | DEBUG    | src.utils.training:fit:226 - Epoch [12/30]: Train Loss = 0.9278, Train Acc = 65.60%, Val Loss = 1.3525, Val Acc = 52.70%
# 2025-04-14 11:24:07.163 | DEBUG    | src.utils.training:fit:226 - Epoch [13/30]: Train Loss = 0.9447, Train Acc = 64.95%, Val Loss = 1.3770, Val Acc = 53.60%
# 2025-04-14 11:24:51.006 | DEBUG    | src.utils.training:fit:226 - Epoch [14/30]: Train Loss = 0.9293, Train Acc = 65.58%, Val Loss = 1.4402, Val Acc = 51.70%
# 2025-04-14 11:25:35.787 | DEBUG    | src.utils.training:fit:226 - Epoch [15/30]: Train Loss = 0.8118, Train Acc = 69.58%, Val Loss = 1.4592, Val Acc = 53.20%
# 2025-04-14 11:26:20.265 | DEBUG    | src.utils.training:fit:226 - Epoch [16/30]: Train Loss = 0.7450, Train Acc = 73.30%, Val Loss = 1.4933, Val Acc = 54.30%
# 2025-04-14 11:27:04.948 | DEBUG    | src.utils.training:fit:226 - Epoch [17/30]: Train Loss = 0.6377, Train Acc = 76.72%, Val Loss = 1.5291, Val Acc = 55.00%
# 2025-04-14 11:27:49.855 | DEBUG    | src.utils.training:fit:226 - Epoch [18/30]: Train Loss = 0.5877, Train Acc = 78.83%, Val Loss = 1.5708, Val Acc = 56.20%
# 2025-04-14 11:28:33.992 | DEBUG    | src.utils.training:fit:226 - Epoch [19/30]: Train Loss = 0.5458, Train Acc = 80.30%, Val Loss = 1.6468, Val Acc = 58.00%
# 2025-04-14 11:29:18.047 | DEBUG    | src.utils.training:fit:226 - Epoch [20/30]: Train Loss = 0.4775, Train Acc = 83.50%, Val Loss = 1.6972, Val Acc = 58.30%
# 2025-04-14 11:30:02.140 | INFO     | src.utils.training:fit:214 - Early stopping at epoch 21
# 2025-04-14 11:30:02.151 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=nq_circuit_meas=defaultX_lr=0.01_ep=30
# 2025-04-14 11:30:02.152 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=nq_circuit, measurement=defaultY, epochs=30, lr=0.01
# 2025-04-14 11:30:51.015 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 11:31:40.888 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 1.8987, Train Acc = 29.20%, Val Loss = 1.6067, Val Acc = 38.30%
# 2025-04-14 11:32:31.057 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.5829, Train Acc = 41.10%, Val Loss = 1.4217, Val Acc = 47.60%
# 2025-04-14 11:33:20.156 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.4144, Train Acc = 46.62%, Val Loss = 1.3084, Val Acc = 52.30%
# 2025-04-14 11:34:09.303 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.2667, Train Acc = 52.52%, Val Loss = 1.2405, Val Acc = 56.60%
# 2025-04-14 11:34:58.533 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.1281, Train Acc = 58.70%, Val Loss = 1.1768, Val Acc = 58.80%
# 2025-04-14 11:35:47.888 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss =
| DEBUG    | src.utils.training:fit:226 - Epoch [15/30]: Train Loss = 0.6546, Train Acc = 76.40%, Val Loss = 1.8232, Val Acc = 54.10%
# 2025-04-14 11:54:49.865 | INFO     | src.utils.training:fit:214 - Early stopping at epoch 16
# 2025-04-14 11:54:49.876 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=ring_circuit_meas=defaultZ_lr=0.01_ep=30
# 2025-04-14 11:54:49.877 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=ring_circuit, measurement=defaultX, epochs=30, lr=0.01
# 2025-04-14 11:55:38.924 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 11:56:19.348 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 1.9132, Train Acc = 26.50%, Val Loss = 1.6765, Val Acc = 34.00%
# 2025-04-14 11:56:59.259 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.6722, Train Acc = 34.83%, Val Loss = 1.5304, Val Acc = 42.80%
# 2025-04-14 11:57:39.332 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.4572, Train Acc = 45.05%, Val Loss = 1.5074, Val Acc = 43.70%
# 2025-04-14 11:58:19.526 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.3475, Train Acc = 49.42%, Val Loss = 1.3496, Val Acc = 49.60%
# 2025-04-14 11:59:00.002 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.2602, Train Acc = 53.40%, Val Loss = 1.3975, Val Acc = 50.70%
# 2025-04-14 11:59:40.287 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 1.2181, Train Acc = 55.35%, Val Loss = 1.3533, Val Acc = 52.10%
# 2025-04-14 12:00:20.555 | DEBUG    | src.utils.training:fit:226 - Epoch [7/30]: Train Loss = 1.0972, Train Acc = 59.65%, Val Loss = 1.3215, Val Acc = 54.10%
# 2025-04-14 12:01:01.495 | DEBUG    | src.utils.training:fit:226 - Epoch [8/30]: Train Loss = 1.0060, Train Acc = 63.92%, Val Loss = 1.4454, Val Acc = 52.80%
# 2025-04-14 12:01:42.114 | DEBUG    | src.utils.training:fit:226 - Epoch [9/30]: Train Loss = 0.8898, Train Acc = 67.08%, Val Loss = 1.3400, Val Acc = 56.40%
# 2025-04-14 12:02:22.749 | DEBUG    | src.utils.training:fit:226 - Epoch [10/30]: Train Loss = 0.8418, Train Acc = 69.58%, Val Loss = 1.4295, Val Acc = 56.50%
# 2025-04-14 12:03:03.680 | DEBUG    | src.utils.training:fit:226 - Epoch [11/30]: Train Loss = 0.7050, Train Acc = 74.90%, Val Loss = 1.4751, Val Acc = 57.00%
# 2025-04-14 12:03:44.729 | DEBUG    | src.utils.training:fit:226 - Epoch [12/30]: Train Loss = 0.6446, Train Acc = 76.72%, Val Loss = 1.5783, Val Acc = 56.00%
# 2025-04-14 12:04:25.787 | DEBUG    | src.utils.training:fit:226 - Epoch [13/30]: Train Loss = 0.5433, Train Acc = 81.15%, Val Loss = 1.7294, Val Acc = 58.10%
# 2025-04-14 12:05:06.620 | DEBUG    | src.utils.training:fit:226 - Epoch [14/30]: Train Loss = 0.4559, Train Acc = 83.70%, Val Loss = 1.9000, Val Acc = 58.60%
# 2025-04-14 12:05:47.919 | DEBUG    | src.utils.training:fit:226 - Epoch [15/30]: Train Loss = 0.3695, Train Acc = 86.08%, Val Loss = 2.1345, Val Acc = 59.00%
# 2025-04-14 12:06:28.948 | DEBUG    | src.utils.training:fit:226 - Epoch [16/30]: Train Loss = 0.2968, Train Acc = 89.47%, Val Loss = 2.3635, Val Acc = 59.40%
# 2025-04-14 12:07:09.939 | INFO     | src.utils.training:fit:214 - Early stopping at epoch 17
# 2025-04-14 12:07:09.947 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=ring_circuit_meas=defaultX_lr=0.01_ep=30
# 2025-04-14 12:07:09.948 | INFO     | __main__:run_experiment:33 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=ring_circuit, measurement=defaultY, epochs=30, lr=0.01
# 2025-04-14 12:07:58.800 | DEBUG    | __main__:run_experiment:135 - Trainer created: early_stopping=True, patience=10, log_mlflow=True
# 2025-04-14 12:08:45.297 | DEBUG    | src.utils.training:fit:226 - Epoch [1/30]: Train Loss = 2.0168, Train Acc = 22.10%, Val Loss = 1.8289, Val Acc = 31.10%
# 2025-04-14 12:09:31.622 | DEBUG    | src.utils.training:fit:226 - Epoch [2/30]: Train Loss = 1.8631, Train Acc = 28.48%, Val Loss = 1.8122, Val Acc = 31.00%
# 2025-04-14 12:10:17.785 | DEBUG    | src.utils.training:fit:226 - Epoch [3/30]: Train Loss = 1.6887, Train Acc = 34.77%, Val Loss = 1.6821, Val Acc = 37.30%
# 2025-04-14 12:11:03.991 | DEBUG    | src.utils.training:fit:226 - Epoch [4/30]: Train Loss = 1.5760, Train Acc = 39.85%, Val Loss = 1.6245, Val Acc = 39.70%
# 2025-04-14 12:11:50.366 | DEBUG    | src.utils.training:fit:226 - Epoch [5/30]: Train Loss = 1.4770, Train Acc = 42.75%, Val Loss = 1.5804, Val Acc = 40.20%
# 2025-04-14 12:12:36.529 | DEBUG    | src.utils.training:fit:226 - Epoch [6/30]: Train Loss = 1.4207, Train Acc = 46.35%, Val Loss = 1.5491, Val Acc = 40.50%
# 2025-04-14 12:13:22.876 | DEBUG    | src.utils.training:fit:226 - Epoch [7/30]: Train Loss = 1.3147, Train Acc = 50.10%, Val Loss = 1.5104, Val Acc = 43.90%
# 2025-04-14 12:14:09.367 | DEBUG    | src.utils.training:fit:226 - Epoch [8/30]: Train Loss = 1.2514, Train Acc = 53.23%, Val Loss = 1.5345, Val Acc = 44.10%
# 2025-04-14 12:14:55.587 | DEBUG    | src.utils.training:fit:226 - Epoch [9/30]: Train Loss = 1.1523, Train Acc = 57.08%, Val Loss = 1.5290, Val Acc = 44.90%
# 2025-04-14 12:15:42.014 | DEBUG    | src.utils.training:fit:226 - Epoch [10/30]: Train Loss = 1.0160, Train Acc = 61.83%, Val Loss = 1.5370, Val Acc = 45.40%
# 2025-04-14 12:16:28.253 | DEBUG    | src.utils.training:fit:226 - Epoch [11/30]: Train Loss = 0.9279, Train Acc = 65.38%, Val Loss = 1.5704, Val Acc = 47.80%
# 2025-04-14 12:17:14.597 | DEBUG    | src.utils.training:fit:226 - Epoch [12/30]: Train Loss = 0.8319, Train Acc = 70.40%, Val Loss = 1.6223, Val Acc = 48.20%
# 2025-04-14 12:18:00.882 | DEBUG    | src.utils.training:fit:226 - Epoch [13/30]: Train Loss = 0.7086, Train Acc = 74.42%, Val Loss = 1.6909, Val Acc = 50.90%
# 2025-04-14 12:18:47.202 | DEBUG    | src.utils.training:fit:226 - Epoch [14/30]: Train Loss = 0.6223, Train Acc = 77.55%, Val Loss = 1.8053, Val Acc = 52.50%
# 2025-04-14 12:19:33.565 | DEBUG    | src.utils.training:fit:226 - Epoch [15/30]: Train Loss = 0.5749, Train Acc = 79.62%, Val Loss = 1.9509, Val Acc = 53.80%
# 2025-04-14 12:20:20.009 | DEBUG    | src.utils.training:fit:226 - Epoch [16/30]: Train Loss = 0.5295, Train Acc = 81.08%, Val Loss = 2.0984, Val Acc = 54.30%
# 2025-04-14 12:21:06.658 | INFO     | src.utils.training:fit:214 - Early stopping at epoch 17
# 2025-04-14 12:21:06.667 | INFO     | __main__:run_experiment:141 - Finished run: HQNN_Parallel_EuroSAT_16x16_emb=amplitude_circuit=ring_circuit_meas=defaultY_lr=0.01_ep=30
