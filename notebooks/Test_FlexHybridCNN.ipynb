# %% [markdown]
# # Imports

# %%
#%cd ..
#!pip install torch==2.6
import torch
import pennylane as qml
from pennylane import numpy as np
from loguru import logger
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='IPython')

import sys
import os
import time

logger.info(f"Current directory: {os.getcwd()}")
sys.path.append("../")

from src.nn.encodings.pennylane_templates import angle_embedding, amplitude_embedding, QAOA_embedding
from src.nn.encodings.IQP_embedding import custom_iqp_embedding
from src.nn.encodings.NQE_embedding import NQE_embedding
from src.nn.encodings.ring_embedding import ring_embedding
from src.nn.encodings.waterfall_embedding import waterfall_embedding

from src.nn.ansatz.no_entanglement_circuit import no_entanglement_random_circuit
from src.nn.ansatz.full_entanglement_circuit import full_entanglement_circuit
from src.nn.ansatz.NQ_circuit import NQ_circuit
from src.nn.ansatz.ring_circuit import ring_circuit

from src.nn.measurements.default import default_measurement

from src.nn.models.hybrid.HQNN_quanv import FlexHybridCNN
from src.utils.training import Trainer
from src.utils.dataset import load_dataset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.backends.cudnn.benchmark = True
# Out:
# 2025-03-11 10:53:50.702 | INFO     | __main__:<module>:14 - Current directory: /home/jovyan/work/user/Demostrador1/QML-Satellite-Image-Classification-main/notebooks

# %% [markdown]
# # Define embeddings

# %%
def build_embedding_configurations():
    """
    Dynamically create a list of embedding configurations based on parameter sweeps.
    """
    embedding_configurations = []

    # ----- Ring Embedding
    for n_repeats in [1, 2, 3]:
        embedding_configurations.append({
            "name": "ring",
            "func": ring_embedding,
            "func_params": {
                "n_repeats": n_repeats
            }
        })

    # ----- Waterfall Embedding
    embedding_configurations.append({
        "name": "waterfall",
        "func": waterfall_embedding,
        "func_params": {
            "weights": None
        }
    })

    # ----- Amplitude Embedding
    embedding_configurations.append({
        "name": "amplitude",
        "func": amplitude_embedding,
        "func_params": {
            "normalize": True,
            "pad_with": 0.0,
        }
    })

    # ----- Angle Embedding 
    for rotation in ["X", "Y", "Z"]:
        embedding_configurations.append({
            "name": f"angle_{rotation}",
            "func": angle_embedding,
            "func_params": {
                "rotation": rotation
            }
        })

    # ----- IQP Embedding 
    for repeats in [1, 2, 3]:
        embedding_configurations.append({
            "name": f"iqp_{repeats}",
            "func": custom_iqp_embedding,
            "func_params": {
                "n_repeats": repeats,
                "pattern": None
            }
        })

    # ----- NQE Embedding
    for repeats in [1, 2, 3]:
        embedding_configurations.append({
            "name": f"nqe_{repeats}",
            "func": NQE_embedding,
            "func_params": {
                "n_repeats": repeats
            }
        })

    # ----- QAOA Embedding
    for local_field in ["X", "Y", "Z"]:
        for n_layers in [1, 2, 3]:
            embedding_configurations.append({
                "name": f"qaoa_{local_field}_{n_layers}",
                "func": QAOA_embedding,
                "func_params": {
                    "weights": None,
                    "local_field": local_field,
                    "n_layers": n_layers
                }
            })

    

    return embedding_configurations

# %% [markdown]
# # Define circuits

# %%
def build_circuit_configurations():
    """
    For each qkernel_shape in [2, 3, 5], create circuit configurations.
    We'll pass the shape forward so we can reinitialize weights properly 
    and also use it in the model.
    """
    configs = []
    for qks in [2, 3]: #[2,3,5]
        # No Entanglement
        configs.append({
            "name": f"no_entanglement_qks{qks}",
            "qkernel_shape": qks,
            "func": no_entanglement_random_circuit,
            "func_params": {
                # We will reinit 'weights' on the fly in the main loop
            }
        })
        # Full Entanglement
        configs.append({
            "name": f"full_entanglement_qks{qks}",
            "qkernel_shape": qks,
            "func": full_entanglement_circuit,
            "func_params": {
                "num_layers": 2
            }
        })
        # NQ circuit
        configs.append({
            "name": f"nq_circuit_qks{qks}",
            "qkernel_shape": qks,
            "func": NQ_circuit,
            "func_params": {
                # We'll fill 'weights' in the loop
            }
        })
        # Ring circuit
        configs.append({
            "name": f"ring_circuit_qks{qks}",
            "qkernel_shape": qks,
            "func": ring_circuit,
            "func_params": {
                # We'll fill 'weights' in the loop
            }
        })
    return configs

# %% [markdown]
# # Define measurements

# %%
measurement_configurations = [
    {
        "name": "defaultZ",
        "func": default_measurement,
        "func_params": {"observable": qml.PauliZ}
    }
]

# %% [markdown]
# # Dataset

# %%
dataset_configurations = [
    {
        "dataset_name": "EuroSAT",
        "limit": 10,
        "image_size": 32,
        "test_size": 0.2,
        "output": "np",
        "allowed_classes": [
            'AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway',
            'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake'
        ]
    },
    {
        "dataset_name": "DeepSat4",
        "limit": 10,
        "image_size": 32,
        "test_size": 0.2,
        "output": "np",
        "allowed_classes": ['BarrenLand', 'Trees', 'Grassland', 'Other']
    },
    {
        "dataset_name": "DeepSat6",
        "limit": 10,
        "image_size": 32,
        "test_size": 0.2,
        "output": "np",
        "allowed_classes": ['BarrenLand', 'Trees', 'Grassland', 'Roads', 'Buildings' , 'WaterBodies']
    },
    {
        "dataset_name": "EuroSAT",
        "limit": 10,
        "image_size": 16,
        "test_size": 0.2,
        "output": "np",
        "allowed_classes": [
            'AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway',
            'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake'
        ]
    },
    {
        "dataset_name": "DeepSat4",
        "limit": 10,
        "image_size": 16,
        "test_size": 0.2,
        "output": "np",
        "allowed_classes": ['BarrenLand', 'Trees', 'Grassland', 'Other']
    },
    {
        "dataset_name": "DeepSat6",
        "limit": 10,
        "image_size": 16,
        "test_size": 0.2,
        "output": "np",
        "allowed_classes": ['BarrenLand', 'Trees', 'Grassland', 'Roads', 'Buildings' , 'WaterBodies']
    }
]

# %% [markdown]
# # Hyperparameters

# %%
hyperparameter_configurations = [
    {
        "epochs": 1,
        "learning_rate": 0.01,
        "early_stopping": True,
        "patience": 3,
        "use_schedulefree": True,
        "use_quantum": False,
        "plot": False,
        "log_mlflow": False
    },
    {
        "epochs": 1,
        "learning_rate": 0.01,
        "early_stopping": True,
        "patience": 3,
        "use_schedulefree": True,
        "use_quantum": True,
        "plot": False,
        "log_mlflow": False
    }
    
    # {
    #    "epochs": 20,
    #    "learning_rate": 0.001,
    #    "early_stopping": False,
    #    "patience": 5,
    #    "use_schedulefree": False,
    #    "use_quantum": False,
    #    "plot": False,
    #    "log_mlflow": False
    # },
    
]

# %% [markdown]
# # Helper function

# %%
def run_experiment(
    dataset_cfg,
    embedding_cfg,
    circuit_cfg,
    measurement_cfg,
    hparams
):
    """
    Prepare data, create model, trainer, and run training for one combination of config.
    """
    # Unpack dataset settings
    dataset_name = dataset_cfg["dataset_name"]
    limit = dataset_cfg["limit"]
    image_size = dataset_cfg["image_size"]
    test_size = dataset_cfg["test_size"]
    output = dataset_cfg["output"]
    allowed_classes = dataset_cfg["allowed_classes"]
    n_classes = len(allowed_classes)

    # Unpack hyperparameters
    epochs = hparams["epochs"]
    lr = hparams["learning_rate"]
    early_stopping = hparams["early_stopping"]
    patience = hparams["patience"]
    use_schedulefree = hparams["use_schedulefree"]
    use_quantum = hparams["use_quantum"]
    plot = hparams["plot"]
    log_mlflow = hparams["log_mlflow"]

    # The circuit dictionary also includes the chosen qkernel_shape
    if use_quantum != False:
        qks = circuit_cfg["qkernel_shape"]

        # Loguru info: Start of run
        logger.info(f"Starting run: dataset={dataset_name}, "
                f"embedding={embedding_cfg['name']}, "
                f"circuit={circuit_cfg['name']}, measurement={measurement_cfg['name']}, "
                f"qkernel_shape={qks}, epochs={epochs}, lr={lr}")

        run_name = (
            f"FlexHybridCNN_{dataset_name}_{image_size}x{image_size}_"
            f"emb={embedding_cfg['name']}_circuit={circuit_cfg['name']}_meas={measurement_cfg['name']}_"
            f"qks={qks}_lr={lr}_ep={epochs}"
        )
    # Create a dictionary of all configurations for MLflow
        mlflow_params = {
            # Dataset parameters
            "dataset_name": dataset_name,
            "limit": limit,
            "image_size": image_size,
            "test_size": test_size,
            "allowed_classes": str(allowed_classes),  # Convert list to string
            
            # Embedding parameters
            "embedding_name": embedding_cfg['name'],
            
            # Circuit parameters
            "circuit_name": circuit_cfg['name'],
            
            # Measurement parameters
            "measurement_name": measurement_cfg['name'],
            
            # Any other relevant parameters you want to track
            "run_timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        }

        embedding_params={
            "func": embedding_cfg["func"],
            "func_params": embedding_cfg["func_params"]
        }

        variational_params={
                "func": circuit_cfg["func"],
                "func_params": circuit_cfg["func_params"]  # includes 'weights' re-init
            }
        measurement_params={
            "func": measurement_cfg["func"],
            "func_params": measurement_cfg["func_params"]
        }
        
    else:
        qks = 2
        
        logger.info(f"Starting Classic run: dataset={dataset_name}, "
                f"epochs={epochs}, lr={lr}")

        run_name = (
            f"FlexHybridCNN_{dataset_name}_{image_size}x{image_size}_"
            f"classic_"
            f"lr={lr}_ep={epochs}"
        )
        mlflow_params = {}
        embedding_params={}
        variational_params={}
        measurement_params={}
        
    mlflow_project_name = f"{dataset_name} {image_size}x{image_size}"
    
    # 1. Load Dataset
    train_loader, val_loader = load_dataset(
        dataset_name,
        output,
        limit,
        allowed_classes,
        image_size,
        test_size,
    )

    # 2. Create model
    model = FlexHybridCNN(
        embedding_params=embedding_params,
        variational_params=variational_params,
        measurement_params=measurement_params,
        n_classes=n_classes,
        use_quantum=use_quantum,
        qkernel_shape=qks,  # pass the chosen shape
        epochs=epochs,
        dataset=dataset_name,
        image_size=image_size
    ) 

    # 3. Create Trainer
    trainer = Trainer(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        epochs=epochs,
        early_stopping=early_stopping,
        patience=patience,
        log=log_mlflow,
        mlflow_project=mlflow_project_name,
        mlflow_run_name=run_name,
        use_quantum=use_quantum,
        plot=plot,
        allowed_classes=allowed_classes,
        lr=lr,
        use_schedulefree=use_schedulefree,
        mlflow_params=mlflow_params,
    )

    logger.debug(f"Trainer created: early_stopping={early_stopping}, "
                 f"patience={patience}, log_mlflow={log_mlflow}")

    # 4. Train
    trainer.fit()

    logger.info(f"Finished run: {run_name}")

# %% [markdown]
# # Main loop

# %%
# 1. Build all embedding configs (with angle, iqp, nqe, qaoa sweeps, etc.)
dynamic_embedding_configurations = build_embedding_configurations()

# 2. Build circuit configs for qkernel_shape in [2,3,5]
circuit_configurations = build_circuit_configurations()

# 3. Nested loops
for hp_cfg in hyperparameter_configurations:
    for dataset_cfg in dataset_configurations:
        if hp_cfg["use_quantum"] == False:
            # Run the experiment
            run_experiment(
                dataset_cfg=dataset_cfg,
                embedding_cfg={},
                circuit_cfg={},
                measurement_cfg={},
                hparams=hp_cfg
            )    
            continue
        
        for emb_cfg in dynamic_embedding_configurations:
            for cir_cfg in circuit_configurations:
                for meas_cfg in measurement_configurations:
                    # Reinitialize circuit weights each iteration, 
                    # based on the current qkernel_shape:
                    qks = cir_cfg["qkernel_shape"]

                    if "no_entanglement" in cir_cfg["name"]:
                        cir_cfg["func_params"]["weights"] = torch.rand(
                            qks**2, device=device
                        ) % np.pi
                    elif "full_entanglement" in cir_cfg["name"]:
                        # e.g. num_layers=2 in func_params, 
                        # so shape = [2, qks^2, 3]
                        num_layers = cir_cfg["func_params"]["num_layers"]
                        cir_cfg["func_params"]["weights"] = torch.randn(
                            num_layers, qks**2, 3, device=device
                        ) % np.pi
                    elif "nq_circuit" in cir_cfg["name"]:
                        # shape = [3*(qks^2), 2]
                        cir_cfg["func_params"]["weights"] = torch.randn(
                            3 * (qks**2), 2, device=device
                        ) % np.pi
                    elif "ring_circuit" in cir_cfg["name"]:
                        # shape = [3*(qks^2), 2]
                        cir_cfg["func_params"]["weights"] = torch.randn(
                            3 * (qks**2), 2, device=device
                        ) % np.pi
                    '''
                    # setting device on GPU if available, else CPU
                    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
                    print('Using device:', device)
                    print()
                    
                    #Additional Info when using cuda
                    if device.type == 'cuda':
                        print(torch.cuda.get_device_name(0))
                        print('Memory Usage:')
                        print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**2,1), 'MB')
                        print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**2,1), 'MB')
                    '''
                    # Run the experiment
                    run_experiment(
                        dataset_cfg=dataset_cfg,
                        embedding_cfg=emb_cfg,
                        circuit_cfg=cir_cfg,
                        measurement_cfg=meas_cfg,
                        hparams=hp_cfg
                    )
# Out:
# 2025-03-11 10:53:54.616 | INFO     | __main__:run_experiment:84 - Starting Classic run: dataset=EuroSAT, epochs=1, lr=0.01
# 2025-03-11 10:53:55.354 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:53:55.775 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3920, Train Acc = 11.25%, Val Loss = 2.1584, Val Acc = 15.00%
# 2025-03-11 10:53:55.777 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_classic_lr=0.01_ep=1
# 2025-03-11 10:53:55.778 | INFO     | __main__:run_experiment:84 - Starting Classic run: dataset=DeepSat4, epochs=1, lr=0.01
# 2025-03-11 10:53:58.618 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:53:58.695 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.3871, Train Acc = 25.00%, Val Loss = 1.4311, Val Acc = 25.00%
# 2025-03-11 10:53:58.697 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat4_32x32_classic_lr=0.01_ep=1
# 2025-03-11 10:53:58.698 | INFO     | __main__:run_experiment:84 - Starting Classic run: dataset=DeepSat6, epochs=1, lr=0.01
# 2025-03-11 10:54:00.963 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:01.041 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7900, Train Acc = 25.00%, Val Loss = 1.6881, Val Acc = 0.00%
# 2025-03-11 10:54:01.043 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_classic_lr=0.01_ep=1
# 2025-03-11 10:54:01.052 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:01.643 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:01.891 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2950, Train Acc = 11.25%, Val Loss = 2.2372, Val Acc = 15.00%
# 2025-03-11 10:54:01.892 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:01.894 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:02.500 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:02.681 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2954, Train Acc = 6.25%, Val Loss = 2.2307, Val Acc = 20.00%
# 2025-03-11 10:54:02.682 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:02.683 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:03.276 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:03.400 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2954, Train Acc = 6.25%, Val Loss = 2.2494, Val Acc = 10.00%
# 2025-03-11 10:54:03.401 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:03.401 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:04.007 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:04.125 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3102, Train Acc = 7.50%, Val Loss = 2.1811, Val Acc = 25.00%
# 2025-03-11 10:54:04.127 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:04.128 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:04.749 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:05.691 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3267, Train Acc = 11.25%, Val Loss = 2.1514, Val Acc = 25.00%
# 2025-03-11 10:54:05.693 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:05.694 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:06.319 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:07.588 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2967, Train Acc = 10.00%, Val Loss = 2.1729, Val Acc = 25.00%
# 2025-03-11 10:54:07.589 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:07.590 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:08.202 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:10.655 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3280, Train Acc = 6.25%, Val Loss = 2.2363, Val Acc = 20.00%
# 2025-03-11 10:54:10.658 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:10.659 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:11.270 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:13.055 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4367, Train Acc = 10.00%, Val Loss = 2.1937, Val Acc = 30.00%
# 2025-03-11 10:54:13.056 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:13.057 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:13.656 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:13.796 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3465, Train Acc = 11.25%, Val Loss = 2.2915, Val Acc = 10.00%
# 2025-03-11 10:54:13.797 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:13.798 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:14.402 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:14.623 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3402, Train Acc = 10.00%, Val Loss = 2.1478, Val Acc = 20.00%
# 2025-03-11 10:54:14.624 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:14.625 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:15.225 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:15.407 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3398, Train Acc = 3.75%, Val Loss = 2.2860, Val Acc = 15.00%
# 2025-03-11 10:54:15.408 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:15.409 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:16.031 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:16.193 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2648, Train Acc = 15.00%, Val Loss = 2.1067, Val Acc = 35.00%
# 2025-03-11 10:54:16.194 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:16.195 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:16.813 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:18.384 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4307, Train Acc = 10.00%, Val Loss = 2.1924, Val Acc = 20.00%
# 2025-03-11 10:54:18.385 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:18.386 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:19.016 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:21.270 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3005, Train Acc = 10.00%, Val Loss = 2.2392, Val Acc = 15.00%
# 2025-03-11 10:54:21.272 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:21.273 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:21.879 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:24.632 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3286, Train Acc = 8.75%, Val Loss = 2.1898, Val Acc = 25.00%
# 2025-03-11 10:54:24.633 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:24.634 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:25.251 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:27.116 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3498, Train Acc = 11.25%, Val Loss = 2.1028, Val Acc = 20.00%
# 2025-03-11 10:54:27.117 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:27.119 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:27.722 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:27.887 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3345, Train Acc = 10.00%, Val Loss = 2.2387, Val Acc = 25.00%
# 2025-03-11 10:54:27.888 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:27.889 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:28.469 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:28.661 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2983, Train Acc = 8.75%, Val Loss = 2.2746, Val Acc = 20.00%
# 2025-03-11 10:54:28.663 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:28.664 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:29.262 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:29.506 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3005, Train Acc = 11.25%, Val Loss = 2.1844, Val Acc = 30.00%
# 2025-03-11 10:54:29.507 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:29.508 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:30.112 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:30.301 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3056, Train Acc = 5.00%, Val Loss = 2.1587, Val Acc = 20.00%
# 2025-03-11 10:54:30.302 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:30.303 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:30.890 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:32.994 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3454, Train Acc = 10.00%, Val Loss = 2.2268, Val Acc = 15.00%
# 2025-03-11 10:54:32.996 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:32.997 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:33.597 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:36.126 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3040, Train Acc = 11.25%, Val Loss = 2.2785, Val Acc = 15.00%
# 2025-03-11 10:54:36.128 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:36.129 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:36.738 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:39.771 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3183, Train Acc = 7.50%, Val Loss = 2.1686, Val Acc = 20.00%
# 2025-03-11 10:54:39.773 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:39.774 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=ring, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:40.377 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:42.907 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3216, Train Acc = 15.00%, Val Loss = 2.1468, Val Acc = 25.00%
# 2025-03-11 10:54:42.909 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=ring_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:42.910 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:43.510 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:43.629 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3398, Train Acc = 12.50%, Val Loss = 2.2451, Val Acc = 10.00%
# 2025-03-11 10:54:43.630 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:43.631 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:44.221 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:44.349 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2948, Train Acc = 11.25%, Val Loss = 2.2110, Val Acc = 30.00%
# 2025-03-11 10:54:44.350 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:44.351 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:44.942 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:45.083 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2864, Train Acc = 16.25%, Val Loss = 2.2030, Val Acc = 5.00%
# 2025-03-11 10:54:45.084 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:45.085 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:45.678 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:45.808 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3045, Train Acc = 10.00%, Val Loss = 2.1757, Val Acc = 30.00%
# 2025-03-11 10:54:45.809 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:45.810 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:46.397 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:47.362 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3921, Train Acc = 6.25%, Val Loss = 2.3143, Val Acc = 20.00%
# 2025-03-11 10:54:47.363 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:47.364 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:47.957 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:49.291 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3046, Train Acc = 10.00%, Val Loss = 2.2578, Val Acc = 35.00%
# 2025-03-11 10:54:49.293 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:49.294 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:49.916 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:52.053 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2964, Train Acc = 10.00%, Val Loss = 2.1956, Val Acc = 20.00%
# 2025-03-11 10:54:52.054 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:52.055 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=waterfall, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:52.653 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:54.154 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3978, Train Acc = 13.75%, Val Loss = 2.1592, Val Acc = 25.00%
# 2025-03-11 10:54:54.155 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=waterfall_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:54:54.156 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:54.764 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:55.348 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4138, Train Acc = 6.25%, Val Loss = 2.3200, Val Acc = 10.00%
# 2025-03-11 10:54:55.349 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:55.350 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:55.950 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:56.544 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3066, Train Acc = 8.75%, Val Loss = 2.3008, Val Acc = 15.00%
# 2025-03-11 10:54:56.545 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:56.546 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:57.140 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:57.753 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3789, Train Acc = 6.25%, Val Loss = 2.3097, Val Acc = 10.00%
# 2025-03-11 10:54:57.755 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:57.755 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:54:58.379 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:54:58.987 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3339, Train Acc = 10.00%, Val Loss = 2.3043, Val Acc = 5.00%
# 2025-03-11 10:54:58.988 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:54:58.989 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:54:59.602 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:55:17.306 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 3.0953, Train Acc = 8.75%, Val Loss = 2.3568, Val Acc = 10.00%
# 2025-03-11 10:55:17.308 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:55:17.309 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:55:17.926 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:55:35.859 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3166, Train Acc = 3.75%, Val Loss = 2.3036, Val Acc = 10.00%
# 2025-03-11 10:55:35.861 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:55:35.862 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:55:36.486 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:55:55.570 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4453, Train Acc = 5.00%, Val Loss = 2.3095, Val Acc = 10.00%
# 2025-03-11 10:55:55.572 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:55:55.573 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=amplitude, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:55:56.166 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:14.422 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.5984, Train Acc = 8.75%, Val Loss = 2.3697, Val Acc = 10.00%
# 2025-03-11 10:56:14.424 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=amplitude_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:14.425 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:15.045 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:15.121 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.5187, Train Acc = 13.75%, Val Loss = 2.2950, Val Acc = 15.00%
# 2025-03-11 10:56:15.121 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:15.122 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:15.741 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:15.840 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2773, Train Acc = 11.25%, Val Loss = 2.2312, Val Acc = 10.00%
# 2025-03-11 10:56:15.841 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:15.842 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:16.461 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:16.571 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3460, Train Acc = 13.75%, Val Loss = 2.2720, Val Acc = 10.00%
# 2025-03-11 10:56:16.572 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:16.573 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:17.193 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:17.282 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3896, Train Acc = 8.75%, Val Loss = 2.2780, Val Acc = 15.00%
# 2025-03-11 10:56:17.283 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:17.284 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:17.899 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:18.293 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.8396, Train Acc = 7.50%, Val Loss = 2.3040, Val Acc = 10.00%
# 2025-03-11 10:56:18.294 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:18.295 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:18.898 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:19.919 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2987, Train Acc = 10.00%, Val Loss = 2.2502, Val Acc = 20.00%
# 2025-03-11 10:56:19.920 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:19.921 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:20.533 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:22.775 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3977, Train Acc = 5.00%, Val Loss = 2.2516, Val Acc = 30.00%
# 2025-03-11 10:56:22.776 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:22.777 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_X, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:23.387 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:24.896 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.6298, Train Acc = 7.50%, Val Loss = 2.3475, Val Acc = 10.00%
# 2025-03-11 10:56:24.899 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_X_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:24.900 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:25.504 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:25.580 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.6861, Train Acc = 8.75%, Val Loss = 2.3322, Val Acc = 10.00%
# 2025-03-11 10:56:25.582 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:25.583 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:26.214 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:26.351 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3113, Train Acc = 8.75%, Val Loss = 2.2912, Val Acc = 25.00%
# 2025-03-11 10:56:26.352 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:26.353 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:26.950 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:27.052 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3313, Train Acc = 16.25%, Val Loss = 2.2672, Val Acc = 10.00%
# 2025-03-11 10:56:27.053 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:27.054 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:27.675 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:27.768 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.5082, Train Acc = 6.25%, Val Loss = 2.2998, Val Acc = 5.00%
# 2025-03-11 10:56:27.769 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:27.770 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:28.369 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:28.867 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.8449, Train Acc = 11.25%, Val Loss = 2.3946, Val Acc = 10.00%
# 2025-03-11 10:56:28.869 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:28.870 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:29.488 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:30.352 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3097, Train Acc = 11.25%, Val Loss = 2.2720, Val Acc = 15.00%
# 2025-03-11 10:56:30.354 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:30.355 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:30.958 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:32.841 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3783, Train Acc = 12.50%, Val Loss = 2.1857, Val Acc = 25.00%
# 2025-03-11 10:56:32.843 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:32.845 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Y, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:33.447 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:34.551 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4382, Train Acc = 5.00%, Val Loss = 2.2034, Val Acc = 25.00%
# 2025-03-11 10:56:34.553 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Y_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:34.554 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:35.138 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:35.285 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4959, Train Acc = 8.75%, Val Loss = 2.3943, Val Acc = 10.00%
# 2025-03-11 10:56:35.286 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:35.287 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:35.877 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:35.989 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3818, Train Acc = 7.50%, Val Loss = 2.3105, Val Acc = 10.00%
# 2025-03-11 10:56:35.990 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:35.991 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:36.612 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:36.852 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4586, Train Acc = 11.25%, Val Loss = 2.4608, Val Acc = 10.00%
# 2025-03-11 10:56:36.854 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:36.855 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:37.446 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:37.642 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.5257, Train Acc = 10.00%, Val Loss = 2.3172, Val Acc = 10.00%
# 2025-03-11 10:56:37.643 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:37.644 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:38.230 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:38.772 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.8752, Train Acc = 13.75%, Val Loss = 2.8626, Val Acc = 10.00%
# 2025-03-11 10:56:38.773 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:38.774 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:39.373 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:40.392 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3353, Train Acc = 7.50%, Val Loss = 2.3047, Val Acc = 10.00%
# 2025-03-11 10:56:40.393 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:40.393 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:40.966 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:42.332 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4530, Train Acc = 5.00%, Val Loss = 2.3683, Val Acc = 10.00%
# 2025-03-11 10:56:42.333 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:42.334 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=angle_Z, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:42.931 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:43.753 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.8495, Train Acc = 12.50%, Val Loss = 2.3741, Val Acc = 10.00%
# 2025-03-11 10:56:43.754 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=angle_Z_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 10:56:43.755 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=iqp_1, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:44.366 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:44.608 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3052, Train Acc = 6.25%, Val Loss = 2.3035, Val Acc = 10.00%
# 2025-03-11 10:56:44.609 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=iqp_1_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:44.611 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=iqp_1, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:45.207 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:45.341 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.2888, Train Acc = 13.75%, Val Loss = 2.2280, Val Acc = 20.00%
# 2025-03-11 10:56:45.342 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=iqp_1_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:45.343 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=iqp_1, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:45.937 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:46.262 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3092, Train Acc = 8.75%, Val Loss = 2.2580, Val Acc = 30.00%
# 2025-03-11 10:56:46.263 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=iqp_1_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:46.264 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=iqp_1, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 10:56:46.845 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:47.015 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.4037, Train Acc = 10.00%, Val Loss = 2.2841, Val Acc = 20.00%
# 2025-03-11 10:56:47.017 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=iqp_1_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 10:56:47.018 | INFO     | __main__:run_experiment:35 - Starting run: dataset=EuroSAT, embedding=iqp_1, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 10:56:47.617 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 10:56:49.022 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 2.3059, Train Acc = 8.75%, Val Loss = 2.3037, Val Acc = 10.00%
# 2025-03-11 10:56:49.023 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_EuroSAT_32x32_emb=iqp_1_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# ...
# 2025-03-11 11:19:15.215 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7814, Train Acc = 25.00%, Val Loss = 13.9861, Val Acc = 33.33%
# 2025-03-11 11:19:15.216 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:15.217 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_1, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:17.646 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:17.708 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7990, Train Acc = 0.00%, Val Loss = 2.2982, Val Acc = 33.33%
# 2025-03-11 11:19:17.709 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:17.710 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_1, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:20.141 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:20.204 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8256, Train Acc = 0.00%, Val Loss = 5.7485, Val Acc = 0.00%
# 2025-03-11 11:19:20.205 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:20.206 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_1, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:22.636 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:22.686 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8133, Train Acc = 25.00%, Val Loss = 5.6172, Val Acc = 33.33%
# 2025-03-11 11:19:22.687 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:22.688 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_1, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:25.122 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:25.415 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7849, Train Acc = 0.00%, Val Loss = 6.2411, Val Acc = 33.33%
# 2025-03-11 11:19:25.416 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:25.417 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_1, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:27.846 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:28.422 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7790, Train Acc = 12.50%, Val Loss = 1.2947, Val Acc = 33.33%
# 2025-03-11 11:19:28.423 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:28.424 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_1, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:30.858 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:31.559 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8022, Train Acc = 12.50%, Val Loss = 1.1769, Val Acc = 33.33%
# 2025-03-11 11:19:31.560 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:31.561 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_1, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:33.993 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:34.403 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8043, Train Acc = 12.50%, Val Loss = 4.6474, Val Acc = 33.33%
# 2025-03-11 11:19:34.404 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_1_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:34.405 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:36.834 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:36.888 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7989, Train Acc = 25.00%, Val Loss = 21.8431, Val Acc = 0.00%
# 2025-03-11 11:19:36.889 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:36.889 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:39.317 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:39.387 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7667, Train Acc = 25.00%, Val Loss = 1.0218, Val Acc = 66.67%
# 2025-03-11 11:19:39.388 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:39.389 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:41.826 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:41.898 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7649, Train Acc = 25.00%, Val Loss = 1.5942, Val Acc = 66.67%
# 2025-03-11 11:19:41.899 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:41.900 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:44.327 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:44.390 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7715, Train Acc = 37.50%, Val Loss = 4.7563, Val Acc = 33.33%
# 2025-03-11 11:19:44.391 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:44.392 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:46.819 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:47.266 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7930, Train Acc = 25.00%, Val Loss = 22.2193, Val Acc = 0.00%
# 2025-03-11 11:19:47.267 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:47.268 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:49.698 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:50.440 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7806, Train Acc = 25.00%, Val Loss = 1.6013, Val Acc = 33.33%
# 2025-03-11 11:19:50.442 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:50.443 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:52.881 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:53.725 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8009, Train Acc = 12.50%, Val Loss = 2.2063, Val Acc = 33.33%
# 2025-03-11 11:19:53.727 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:53.728 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_2, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:19:56.162 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:56.743 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8323, Train Acc = 0.00%, Val Loss = 3.2952, Val Acc = 33.33%
# 2025-03-11 11:19:56.745 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_2_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:19:56.746 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=no_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:19:59.174 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:19:59.243 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8137, Train Acc = 0.00%, Val Loss = 2.2033, Val Acc = 66.67%
# 2025-03-11 11:19:59.244 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=no_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:19:59.245 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=full_entanglement_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:20:01.675 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:20:01.758 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7876, Train Acc = 12.50%, Val Loss = 2.2200, Val Acc = 0.00%
# 2025-03-11 11:20:01.760 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=full_entanglement_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:20:01.761 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=nq_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:20:04.189 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:20:04.277 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8198, Train Acc = 0.00%, Val Loss = 2.6245, Val Acc = 33.33%
# 2025-03-11 11:20:04.279 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=nq_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:20:04.279 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=ring_circuit_qks2, measurement=defaultZ, qkernel_shape=2, epochs=1, lr=0.01
# 2025-03-11 11:20:06.709 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:20:06.786 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7496, Train Acc = 12.50%, Val Loss = 6.8186, Val Acc = 33.33%
# 2025-03-11 11:20:06.787 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=ring_circuit_qks2_meas=defaultZ_qks=2_lr=0.01_ep=1
# 2025-03-11 11:20:06.788 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=no_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:20:09.226 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:20:09.858 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7709, Train Acc = 25.00%, Val Loss = 12.1808, Val Acc = 33.33%
# 2025-03-11 11:20:09.860 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=no_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:20:09.861 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=full_entanglement_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:20:12.361 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:20:13.246 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7848, Train Acc = 25.00%, Val Loss = 1.7927, Val Acc = 16.67%
# 2025-03-11 11:20:13.248 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=full_entanglement_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:20:13.249 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=nq_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:20:15.677 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:20:16.694 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.7730, Train Acc = 12.50%, Val Loss = 1.0362, Val Acc = 33.33%
# 2025-03-11 11:20:16.697 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=nq_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
# 2025-03-11 11:20:16.697 | INFO     | __main__:run_experiment:35 - Starting run: dataset=DeepSat6, embedding=qaoa_Z_3, circuit=ring_circuit_qks3, measurement=defaultZ, qkernel_shape=3, epochs=1, lr=0.01
# 2025-03-11 11:20:19.127 | DEBUG    | __main__:run_experiment:141 - Trainer created: early_stopping=True, patience=3, log_mlflow=False
# 2025-03-11 11:20:19.863 | DEBUG    | src.utils.training:fit:226 - Epoch [1/1]: Train Loss = 1.8003, Train Acc = 25.00%, Val Loss = 3.4846, Val Acc = 33.33%
# 2025-03-11 11:20:19.865 | INFO     | __main__:run_experiment:147 - Finished run: FlexHybridCNN_DeepSat6_32x32_emb=qaoa_Z_3_circuit=ring_circuit_qks3_meas=defaultZ_qks=3_lr=0.01_ep=1
